# %%
from LangGraphAgent import compliar_agente
from tools.my_graph_tools import turbinar_app

app = turbinar_app(compliar_agente())

# %%
app.view()

# %%
app.nice_call("Quantas notas fiscais estão na base de dados?")
# Out:
# --- AGENT EXECUTION LOG ---
#
# --- Message 1 ---
#   🤖 **System Message:**
#     Content: You are a helpful assistant. Your job is to answer questions related to the contents of one or more CSV files
#     that you have to extract from a .zip file. So before answering any question you need to find the zip file
#     available to you, extarct it and only then you can try to answer the user inquiry.
#
# --- Message 2 ---
#   👤 **Human Message:**
#     Content: Quantas notas fiscais estão na base de dados?
#
# --- Message 3 ---
#   🧠 **AI Message (Thought/Action):**
#     Tool Calls:
#       - Name: list_available_zip_files
#         Arguments: {}
#         Tool Call ID: call_XH4lqljZDtTTm36imR4gOrBf
#     Finish Reason: tool_calls
#
# --- Message 4 ---
#   🛠️ **Tool Message (Tool Output):**
#     Tool Call ID: call_XH4lqljZDtTTm36imR4gOrBf
#     Content: {'zip_files': ['CSV_FILES.zip'], 'intermediate_steps': ['list_available_zip_files']}
#
# --- Message 5 ---
# ...

# %%
app.nice_call("Qual o valor total das notas emitidas entre os dias 10 de Janeiro de 2024 e 20 de Janeiro de 2024")
# Out:
# --- AGENT EXECUTION LOG ---
#
# --- Message 1 ---
#   🤖 **System Message:**
#     Content: You are a helpful assistant. Your job is to answer questions related to the contents of one or more CSV files
#     that you have to extract from a .zip file. So before answering any question you need to find the zip file
#     available to you, extarct it and only then you can try to answer the user inquiry.
#
# --- Message 2 ---
#   👤 **Human Message:**
#     Content: Qual o valor total das notas emitidas entre os dias 10 de Janeiro de 2024 e 20 de Janeiro de 2024
#
# --- Message 3 ---
#   🧠 **AI Message (Thought/Action):**
#     Tool Calls:
#       - Name: list_available_zip_files
#         Arguments: {}
#         Tool Call ID: call_uLm9Re46g2KUZ8M4A7fwNnOA
#     Finish Reason: tool_calls
#
# --- Message 4 ---
#   🛠️ **Tool Message (Tool Output):**
#     Tool Call ID: call_uLm9Re46g2KUZ8M4A7fwNnOA
# ...

# %%
app.nice_call("Qual a empresa que mais fez compras (recebeu notas) no estado do Paraná?")
# Out:
# --- AGENT EXECUTION LOG ---
#
# --- Message 1 ---
#   🤖 **System Message:**
#     Content: You are a helpful assistant. Your job is to answer questions related to the contents of one or more CSV files
#     that you have to extract from a .zip file. So before answering any question you need to find the zip file
#     available to you, extarct it and only then you can try to answer the user inquiry.
#
# --- Message 2 ---
#   👤 **Human Message:**
#     Content: Qual a empresa que mais fez compras (recebeu notas) no estado do Paraná?
#
# --- Message 3 ---
#   🧠 **AI Message (Thought/Action):**
#     Tool Calls:
#       - Name: list_available_zip_files
#         Arguments: {}
#         Tool Call ID: call_irYFUbqc8CjxQGqQZJ67gaiP
#     Finish Reason: tool_calls
#
# --- Message 4 ---
#   🛠️ **Tool Message (Tool Output):**
#     Tool Call ID: call_irYFUbqc8CjxQGqQZJ67gaiP
#     Content: {'zip_files': ['CSV_FILES.zip'], 'intermediate_steps': ['list_available_zip_files']}
#
# ...

# %%
app.nice_call("Alguma empresa comprou alimentos?")
# Out:
# --- AGENT EXECUTION LOG ---
#
# --- Message 1 ---
#   🤖 **System Message:**
#     Content: You are a helpful assistant. Your job is to answer questions related to the contents of one or more CSV files
#     that you have to extract from a .zip file. So before answering any question you need to find the zip file
#     available to you, extarct it and only then you can try to answer the user inquiry.
#
# --- Message 2 ---
#   👤 **Human Message:**
#     Content: Alguma empresa comprou alimentos?
#
# --- Message 3 ---
#   🧠 **AI Message (Thought/Action):**
#     Tool Calls:
#       - Name: list_available_zip_files
#         Arguments: {}
#         Tool Call ID: call_getr3f2qckJnYfjWH9bSFPGR
#     Finish Reason: tool_calls
#
# --- Message 4 ---
#   🛠️ **Tool Message (Tool Output):**
#     Tool Call ID: call_getr3f2qckJnYfjWH9bSFPGR
#     Content: {'zip_files': ['CSV_FILES.zip'], 'intermediate_steps': ['list_available_zip_files']}
#
# --- Message 5 ---
# ...

# %%
app.nice_call("Qual o valor total das notas emitidas sobre produtos alimentícios??")
# Out:
# --- AGENT EXECUTION LOG ---
#
# --- Message 1 ---
#   🤖 **System Message:**
#     Content: You are a helpful assistant. Your job is to answer questions related to the contents of one or more CSV files
#     that you have to extract from a .zip file. So before answering any question you need to find the zip file
#     available to you, extarct it and only then you can try to answer the user inquiry.
#
# --- Message 2 ---
#   👤 **Human Message:**
#     Content: Qual o valor total das notas emitidas sobre produtos alimentícios??
#
# --- Message 3 ---
#   🧠 **AI Message (Thought/Action):**
#     Tool Calls:
#       - Name: list_available_zip_files
#         Arguments: {}
#         Tool Call ID: call_BP0MdF6eNHcLvm7rUp6RyRaM
#     Finish Reason: tool_calls
#
# --- Message 4 ---
#   🛠️ **Tool Message (Tool Output):**
#     Tool Call ID: call_BP0MdF6eNHcLvm7rUp6RyRaM
#     Content: {'zip_files': ['CSV_FILES.zip'], 'intermediate_steps': ['list_available_zip_files']}
#
# --- Message 5 ---
# ...
